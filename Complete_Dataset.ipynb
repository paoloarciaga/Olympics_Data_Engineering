# %%
# Import Dependencies and Setup
import pandas as pd
import numpy as np
from pathlib import Path

# Store filepaths into variables
results_cleaned_to_load = Path("results_cleaned.csv")
athletes_cleaned_to_load = Path("cleaned_olympic_athletes.csv")

# Read Results and Athletes Data Files and store into Pandas DataFrames
results_data = pd.read_csv(results_cleaned_to_load)
athletes_data = pd.read_csv(athletes_cleaned_to_load) 

# Combine the data into a single dataset 
complete_dataset = pd.merge(results_data, athletes_data, how="left", on=["athlete_url"])
complete_dataset.head(30)
# Out:
# /var/folders/05/65bg2tns3nq_qsnl_7y8p69r0000gn/T/ipykernel_35846/2462207859.py:11: DtypeWarning: Columns (14,15,16,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   results_data = pd.read_csv(results_cleaned_to_load)
#     discipline_title   event_title     slug_game participant_type medal_type  \
# 0   Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 1   Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 2   Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 3   Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 4   Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 5   Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 6   Freestyle Skiing  Men's Moguls  beijing-2022          Athlete     BRONZE
# 7   Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 8   Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 9   Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 10  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 11  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 12  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 13  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 14  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 15  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 16  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete     SILVER
# 17  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 18  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete       GOLD
# 19  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 20  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 21  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 22  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 23  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 24  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 25  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 26  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 27  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 28  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 29  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
#
#    rank_equal rank_position                country_name country_3_letter_code  \
# 0       False             6                   Australia                   AUS
# 1       False            17                      Sweden                   SWE
# 2       False            16    United States of America                   USA
# 3       False            19                     Finland                   FIN
# 4       False             8                  Kazakhstan                   KAZ
# 5       False            29                   Australia                   AUS
# 6       False             3                       Japan                   JPN
# 7       False             7                       Japan                   JPN
# 8       False            26                      Canada                   CAN
# 9       False            24                   Australia                   AUS
# 10      False            21                  Kazakhstan                   KAZ
# 11      False             9                       Japan                   JPN
# 12      False            10                   Australia                   AUS
# 13      False            28                     Finland                   FIN
# 14      False            18                 Switzerland                   SUI
# 15      False            27               Great Britain                   GBR
# 16      False             2                      Canada                   CAN
# 17      False            23                       Japan                   JPN
# 18      False             1                      Sweden                   SWE
# 19      False            25    United States of America                   USA
# 20      False            30  People's Republic of China                   CHN
# 21      False             4                      France                   FRA
# 22      False            14    United States of America                   USA
# 23      False             5    United States of America                   USA
# 24      False            11                      France                   FRA
# 25      False            20                     Finland                   FIN
# 26      False            13                         ROC                   ROC
# 27      False            12                         ROC                   ROC
# 28      False            15                      Sweden                   SWE
# 29      False            22                      Sweden                   SWE
#
#                                           athlete_url  ... athlete2_last_name  \
# 0   https://olympics.com/en/athletes/cooper-woods-...  ...                NaN
# 1           https://olympics.com/en/athletes/elofsson  ...                NaN
# 2      https://olympics.com/en/athletes/dylan-walczyk  ...                NaN
# 3      https://olympics.com/en/athletes/olli-penttala  ...                NaN
# 4           https://olympics.com/en/athletes/reikherd  ...                NaN
# 5        https://olympics.com/en/athletes/matt-graham  ...                NaN
# 6    https://olympics.com/en/athletes/ikuma-horishima  ...                NaN
# 7        https://olympics.com/en/athletes/daichi-hara  ...                NaN
# 8     https://olympics.com/en/athletes/laurent-dumais  ...                NaN
# 9     https://olympics.com/en/athletes/james-matheson  ...                NaN
# 10    https://olympics.com/en/athletes/pavel-kolmakov  ...                NaN
# 11   https://olympics.com/en/athletes/kosuke-sugimoto  ...                NaN
# 12    https://olympics.com/en/athletes/brodie-summers  ...                NaN
# 13    https://olympics.com/en/athletes/severi-vierela  ...                NaN
# 14        https://olympics.com/en/athletes/marco-tade  ...                NaN
# 15   https://olympics.com/en/athletes/william-feneley  ...                NaN
# 16  https://olympics.com/en/athletes/mikael-kingsbury  ...                NaN
# 17        https://olympics.com/en/athletes/so-matsuda  ...                NaN
# 18          https://olympics.com/en/athletes/wallberg  ...                NaN
# 19    https://olympics.com/en/athletes/bradley-wilson  ...                NaN
# 20         https://olympics.com/en/athletes/yang-zhao  ...                NaN
# 21    https://olympics.com/en/athletes/benjamin-cavet  ...                NaN
# 22     https://olympics.com/en/athletes/cole-mcdonald  ...                NaN
# 23         https://olympics.com/en/athletes/nick-page  ...                NaN
# 24  https://olympics.com/en/athletes/sacha-theocharis  ...                NaN
# 25      https://olympics.com/en/athletes/jimi-salonen  ...                NaN
# 26  https://olympics.com/en/athletes/nikita-novitskii  ...                NaN
# 27    https://olympics.com/en/athletes/nikita-andreev  ...                NaN
# 28  https://olympics.com/en/athletes/ludvig-fjalls...  ...                NaN
# 29    https://olympics.com/en/athletes/oskar-elofsson  ...                NaN
#
#    athlete2_url first_name_y      last_name_y games_participations  \
# 0           NaN       Cooper  Woods-Topalovic                  1.0
# 1           NaN        Felix         Elofsson                  2.0
# 2           NaN        Dylan          Walczyk                  1.0
# 3           NaN         Olli         Penttala                  1.0
# 4           NaN      Dmitriy         Reikherd                  1.0
# 5           NaN         Matt           Graham                  3.0
# 6           NaN        Ikuma        Horishima                  2.0
# 7           NaN       Daichi             Hara                  2.0
# 8           NaN      Laurent           Dumais                  1.0
# 9           NaN        James         Matheson                  2.0
# 10          NaN        Pavel         Kolmakov                  3.0
# 11          NaN       Kosuke         Sugimoto                  1.0
# 12          NaN       Brodie          Summers                  3.0
# 13          NaN       Severi          Vierela                  1.0
# 14          NaN        Marco             Tade                  1.0
# 15          NaN      William          Feneley                  1.0
# 16          NaN       Mikael        Kingsbury                  3.0
# 17          NaN           So          Matsuda                  1.0
# 18          NaN       Walter         Wallberg                  2.0
# 19          NaN      Bradley           Wilson                  3.0
# 20          NaN         Yang             Zhao                  1.0
# 21          NaN     Benjamin            Cavet                  3.0
# 22          NaN         Cole         Mcdonald                  1.0
# 23          NaN         Nick             Page                  1.0
# 24          NaN        Sacha       Theocharis                  2.0
# 25          NaN         Jimi          Salonen                  3.0
# 26          NaN       Nikita        Novitskii                  1.0
# 27          NaN       Nikita          Andreev                  1.0
# 28          NaN       Ludvig       Fjallstrom                  3.0
# 29          NaN        Oskar         Elofsson                  1.0
#
#    gold_medals silver_medals bronze_medals    first_olympics athlete_YOB
# 0          0.0           0.0           0.0      Beijing 2022      2000.0
# 1          0.0           0.0           0.0  PyeongChang 2018      1995.0
# 2          0.0           0.0           0.0      Beijing 2022      1993.0
# 3          0.0           0.0           0.0      Beijing 2022      1995.0
# 4          0.0           0.0           0.0      Beijing 2022      1989.0
# 5          0.0           1.0           0.0        Sochi 2014      1994.0
# 6          0.0           0.0           1.0  PyeongChang 2018      1997.0
# 7          0.0           0.0           1.0  PyeongChang 2018      1997.0
# 8          0.0           0.0           0.0      Beijing 2022      1996.0
# 9          0.0           0.0           0.0  PyeongChang 2018      1995.0
# 10         0.0           0.0           0.0        Sochi 2014      1996.0
# 11         0.0           0.0           0.0      Beijing 2022      1994.0
# 12         0.0           0.0           0.0        Sochi 2014      1993.0
# 13         0.0           0.0           0.0      Beijing 2022      2001.0
# 14         0.0           0.0           0.0      Beijing 2022      1995.0
# 15         0.0           0.0           0.0      Beijing 2022      1999.0
# 16         1.0           2.0           0.0        Sochi 2014      1992.0
# 17         0.0           0.0           0.0      Beijing 2022      1999.0
# 18         1.0           0.0           0.0  PyeongChang 2018      2000.0
# 19         0.0           0.0           0.0        Sochi 2014      1992.0
# 20         0.0           0.0           0.0      Beijing 2022      1992.0
# 21         0.0           0.0           0.0        Sochi 2014      1994.0
# 22         0.0           0.0           0.0      Beijing 2022      2003.0
# 23         0.0           0.0           0.0      Beijing 2022      2002.0
# 24         0.0           0.0           0.0  PyeongChang 2018      1990.0
# 25         0.0           0.0           0.0        Sochi 2014      1994.0
# 26         0.0           0.0           0.0      Beijing 2022      2000.0
# 27         0.0           0.0           0.0      Beijing 2022      2004.0
# 28         0.0           0.0           0.0        Sochi 2014      1993.0
# 29         0.0           0.0           0.0      Beijing 2022      1998.0
#
# [30 rows x 28 columns]

# %%
# Show all headers in the new DataFrame
headers = complete_dataset.columns.tolist()
headers
# Out:
# ['discipline_title',
#  'event_title',
#  'slug_game',
#  'participant_type',
#  'medal_type',
#  'rank_equal',
#  'rank_position',
#  'country_name',
#  'country_3_letter_code',
#  'athlete_url',
#  'value_unit',
#  'value_type',
#  'first_name_x',
#  'last_name_x',
#  'athlete1_first_name',
#  'athlete1_last_name',
#  'athlete1_url',
#  'athlete2_first_name',
#  'athlete2_last_name',
#  'athlete2_url',
#  'first_name_y',
#  'last_name_y',
#  'games_participations',
#  'gold_medals',
#  'silver_medals',
#  'bronze_medals',
#  'first_olympics',
#  'athlete_YOB']

# %%
# Count how many total athletes are in this csv 
unique_athletes_count = len(complete_dataset[['athlete_url', 'athlete1_url', 'athlete2_url']].stack().unique())
unique_athletes_count
# Out:
# 75930

# %%
# Concatenate URLs from athlete_url, athlete1_url, and athlete2_url columns
urls = complete_dataset[['athlete_url', 'athlete1_url', 'athlete2_url']].stack().reset_index(drop=True)

# Remove duplicates
unique_urls = urls.drop_duplicates()

# Create a new column in the DataFrame and assign the unique URLs to it
complete_dataset['unique_urls'] = unique_urls

# Print the DataFrame to verify the changes
complete_dataset.head()
# Out:
#    discipline_title   event_title     slug_game participant_type medal_type  \
# 0  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 1  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 2  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 3  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 4  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
#
#   rank_equal rank_position              country_name country_3_letter_code  \
# 0      False             6                 Australia                   AUS
# 1      False            17                    Sweden                   SWE
# 2      False            16  United States of America                   USA
# 3      False            19                   Finland                   FIN
# 4      False             8                Kazakhstan                   KAZ
#
#                                          athlete_url  ... athlete2_url  \
# 0  https://olympics.com/en/athletes/cooper-woods-...  ...          NaN
# 1          https://olympics.com/en/athletes/elofsson  ...          NaN
# 2     https://olympics.com/en/athletes/dylan-walczyk  ...          NaN
# 3     https://olympics.com/en/athletes/olli-penttala  ...          NaN
# 4          https://olympics.com/en/athletes/reikherd  ...          NaN
#
#   first_name_y      last_name_y games_participations gold_medals  \
# 0       Cooper  Woods-Topalovic                  1.0         0.0
# 1        Felix         Elofsson                  2.0         0.0
# 2        Dylan          Walczyk                  1.0         0.0
# 3         Olli         Penttala                  1.0         0.0
# 4      Dmitriy         Reikherd                  1.0         0.0
#
#   silver_medals bronze_medals    first_olympics athlete_YOB  \
# 0           0.0           0.0      Beijing 2022      2000.0
# 1           0.0           0.0  PyeongChang 2018      1995.0
# 2           0.0           0.0      Beijing 2022      1993.0
# 3           0.0           0.0      Beijing 2022      1995.0
# 4           0.0           0.0      Beijing 2022      1989.0
#
#                                          unique_urls
# 0  https://olympics.com/en/athletes/cooper-woods-...
# 1          https://olympics.com/en/athletes/elofsson
# 2     https://olympics.com/en/athletes/dylan-walczyk
# 3     https://olympics.com/en/athletes/olli-penttala
# 4          https://olympics.com/en/athletes/reikherd
#
# [5 rows x 29 columns]

# %%
# Count the number of unique URLs in the 'unique_urls' column
unique_urls_count = complete_dataset['unique_urls'].nunique()
unique_urls_count
# Out:
# 75930

# %%
# Initialize a set to store unique combinations of first and last names
unique_names_set = set()

# Iterate through rows and add unique combinations to the set
for row in complete_dataset.itertuples(index=False):
    unique_names_set.add((row.first_name_x, row.last_name_x))
    unique_names_set.add((row.first_name_y, row.last_name_y))

# Convert the set to a list of tuples
full_names = list(unique_names_set)

# Convert the list of tuples to a DataFrame
unique_names_df = pd.DataFrame(full_names, columns=['first_name', 'last_name'])

# Print the DataFrame to verify the changes
unique_names_df.head()
# Out:
#   first_name         last_name
# 0   Yan-hong                Ma
# 1      Pawel             Wasek
# 2  Jean-marc           Chabloz
# 3       Jean  Pierre-Mvuyekure
# 4     Miriam       Blasco Soto

# %%
# Drop the row containing 'Cooper' and 'Woods-topalovic'
unique_names_df.drop(unique_names_df[(unique_names_df['first_name'] == 'Cooper') & (unique_names_df['last_name'] == 'Woods-topalovic')].index, inplace=True)

# Reset index
unique_names_df.reset_index(drop=True, inplace=True)

# Print the updated unique_names_df
unique_names_df.head()
# Out:
#   first_name         last_name
# 0   Yan-hong                Ma
# 1      Pawel             Wasek
# 2  Jean-marc           Chabloz
# 3       Jean  Pierre-Mvuyekure
# 4     Miriam       Blasco Soto

# %%
# Count the number of unique URLs in the 'unique_urls' column
unique_names_df = unique_names_df['first_name'].nunique()
unique_names_df
# Out:
# 20203

# %%
# Drop the specified columns
complete_dataset.drop(['athlete2_last_name','athlete2_first_name','athlete1_last_name','athlete1_first_name','first_olympics','last_name_y','first_name_y','last_name_x','first_name_x','value_type','value_unit','rank_position','rank_equal','athlete_url', 'athlete1_url', 'athlete2_url'], axis=1, inplace=True)
complete_dataset.head()
# Out:
#    discipline_title   event_title     slug_game participant_type medal_type  \
# 0  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 1  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 2  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 3  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 4  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
#
#                country_name country_3_letter_code  games_participations  \
# 0                 Australia                   AUS                   1.0
# 1                    Sweden                   SWE                   2.0
# 2  United States of America                   USA                   1.0
# 3                   Finland                   FIN                   1.0
# 4                Kazakhstan                   KAZ                   1.0
#
#    gold_medals  silver_medals  bronze_medals  athlete_YOB  \
# 0          0.0            0.0            0.0       2000.0
# 1          0.0            0.0            0.0       1995.0
# 2          0.0            0.0            0.0       1993.0
# 3          0.0            0.0            0.0       1995.0
# 4          0.0            0.0            0.0       1989.0
#
#                                          unique_urls
# 0  https://olympics.com/en/athletes/cooper-woods-...
# 1          https://olympics.com/en/athletes/elofsson
# 2     https://olympics.com/en/athletes/dylan-walczyk
# 3     https://olympics.com/en/athletes/olli-penttala
# 4          https://olympics.com/en/athletes/reikherd

# %%
# Rename the column
complete_dataset.rename(columns={'unique_urls': 'athlete_url'}, inplace=True)
complete_dataset.head()
# Out:
#    discipline_title   event_title     slug_game participant_type medal_type  \
# 0  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 1  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 2  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 3  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
# 4  Freestyle Skiing  Men's Moguls  beijing-2022          Athlete        NaN
#
#                country_name country_3_letter_code  games_participations  \
# 0                 Australia                   AUS                   1.0
# 1                    Sweden                   SWE                   2.0
# 2  United States of America                   USA                   1.0
# 3                   Finland                   FIN                   1.0
# 4                Kazakhstan                   KAZ                   1.0
#
#    gold_medals  silver_medals  bronze_medals  athlete_YOB  \
# 0          0.0            0.0            0.0       2000.0
# 1          0.0            0.0            0.0       1995.0
# 2          0.0            0.0            0.0       1993.0
# 3          0.0            0.0            0.0       1995.0
# 4          0.0            0.0            0.0       1989.0
#
#                                          athlete_url
# 0  https://olympics.com/en/athletes/cooper-woods-...
# 1          https://olympics.com/en/athletes/elofsson
# 2     https://olympics.com/en/athletes/dylan-walczyk
# 3     https://olympics.com/en/athletes/olli-penttala
# 4          https://olympics.com/en/athletes/reikherd

# %%
# Count the number of unique URLs in the 'unique_urls' column
complete_dataset_count = complete_dataset['athlete_url'].nunique()
complete_dataset_count
# Out:
# 75930

# %%
complete_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162816 entries, 0 to 162815
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   discipline_title       162816 non-null  object
#  1   event_title            162816 non-null  object
#  2   slug_game              162816 non-null  object
#  3   participant_type       162816 non-null  object
#  4   medal_type             20211 non-null   object
#  5   country_name           162816 non-null  object
#  6   country_3_letter_code  162816 non-null  object
#  7   games_participations   129944 non-null  float64
#  8   gold_medals            129944 non-null  float64
#  9   silver_medals          129944 non-null  float64
#  10  bronze_medals          129944 non-null  float64
#  11  athlete_YOB            129944 non-null  float64
#  12  athlete_url            75930 non-null   object
# dtypes: float64(5), object(8)
# memory usage: 16.1+ MB

# %%
# Check for null values in the 'athlete_url' column
null_values_before = complete_dataset['athlete_url'].isnull().sum()
print("Total null values before replacement:", null_values_before)

# Generate unique identifiers for null values
unique_identifiers = ["unique_" + str(i) for i in range(1, null_values_before + 1)]

# Replace null values in 'athlete_url' column with unique identifiers
complete_dataset.loc[complete_dataset['athlete_url'].isnull(), 'athlete_url'] = unique_identifiers

# Check for null values in the 'athlete_url' column after replacement
null_values_after = complete_dataset['athlete_url'].isnull().sum()
print("Total null values after replacement:", null_values_after)

if null_values_after > 0:
    print("There are still null values in the 'athlete_url' column.")
else:
    print("All null values in the 'athlete_url' column have been successfully replaced.")
# Out:
# Total null values before replacement: 86886
# Total null values after replacement: 0
# All null values in the 'athlete_url' column have been successfully replaced.

# %%
# Make a copy of complete_dataset to ensure it doesn't affect the original DataFrame
filtered_dataset = complete_dataset.copy()

# Check for null values in the 'athlete_url' column in complete_dataset
null_values_complete = complete_dataset['athlete_url'].isnull().sum()
print("Total null values in complete_dataset:", null_values_complete)

# Generate unique identifiers for null values in complete_dataset
unique_identifiers = ["unique_" + str(i) for i in range(1, null_values_complete + 1)]

# Replace null values in 'athlete_url' column in complete_dataset with unique identifiers
complete_dataset.loc[complete_dataset['athlete_url'].isnull(), 'athlete_url'] = unique_identifiers

# Check for null values in the 'athlete_url' column in filtered_dataset before update
null_values_filtered_before = filtered_dataset['athlete_url'].isnull().sum()
print("Total null values in filtered_dataset before:", null_values_filtered_before)

# Update filtered_dataset to reflect the changes made in complete_dataset
filtered_dataset['athlete_url'] = complete_dataset['athlete_url']

# Check for null values in the 'athlete_url' column in filtered_dataset after update
null_values_filtered_after = filtered_dataset['athlete_url'].isnull().sum()
print("Total null values in filtered_dataset after:", null_values_filtered_after)

if null_values_filtered_after > 0:
    print("There are still null values in the 'athlete_url' column of filtered_dataset.")
else:
    print("All null values in the 'athlete_url' column of filtered_dataset have been successfully replaced.")
# Out:
# Total null values in complete_dataset: 0
# Total null values in filtered_dataset before: 0
# Total null values in filtered_dataset after: 0
# All null values in the 'athlete_url' column of filtered_dataset have been successfully replaced.

# %%
complete_dataset.to_csv('clean_combined.csv', index=False)
