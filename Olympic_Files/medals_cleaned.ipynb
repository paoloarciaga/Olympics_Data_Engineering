# %%
# Import dependencies
import pandas as pd
import numpy as np
from pathlib import Path
import re
pd.set_option('max_colwidth', 400)

# %%
# File to Load (Remember to Change These)
Olympic_games_medals_data = Path("Olympic_Files/olympic_medals.csv")
Olympic_games_olympic_results_data = Path("Olympic_Files/olympic_results.csv")

# Read medals and results Data File and store into Pandas DataFrames
medals_data = pd.read_csv(Olympic_games_medals_data)
medals_data.head()
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 2          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 3          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 4          Curling  beijing-2022  Mixed Doubles        Mixed     BRONZE
#
#   participant_type participant_title  \
# 0         GameTeam             Italy
# 1         GameTeam             Italy
# 2         GameTeam            Norway
# 3         GameTeam            Norway
# 4         GameTeam            Sweden
#
#                                              athlete_url  \
# 0  https://olympics.com/en/athletes/stefania-constantini
# 1          https://olympics.com/en/athletes/amos-mosaner
# 2      https://olympics.com/en/athletes/kristin-skaslien
# 3    https://olympics.com/en/athletes/magnus-nedregotten
# 4         https://olympics.com/en/athletes/almida-de-val
#
#       athlete_full_name country_name country_code country_3_letter_code
# 0  Stefania CONSTANTINI        Italy           IT                   ITA
# 1          Amos MOSANER        Italy           IT                   ITA
# 2      Kristin SKASLIEN       Norway           NO                   NOR
# 3    Magnus NEDREGOTTEN       Norway           NO                   NOR
# 4         Almida DE VAL       Sweden           SE                   SWE

# %%
medals_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21697 entries, 0 to 21696
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   discipline_title       21697 non-null  object
#  1   slug_game              21697 non-null  object
#  2   event_title            21697 non-null  object
#  3   event_gender           21697 non-null  object
#  4   medal_type             21697 non-null  object
#  5   participant_type       21697 non-null  object
#  6   participant_title      6584 non-null   object
#  7   athlete_url            17027 non-null  object
#  8   athlete_full_name      18073 non-null  object
#  9   country_name           21697 non-null  object
#  10  country_code           20195 non-null  object
#  11  country_3_letter_code  21697 non-null  object
# dtypes: object(12)
# memory usage: 2.0+ MB

# %%
medals_data[['first_name', 'last_name']] = medals_data ["athlete_full_name"].str.split(' ', n=1, expand=True)
medals_data['last_name'] = medals_data['last_name'].str.lower()
medals_data['first_name'] = medals_data['first_name'].str.capitalize()
medals_data['last_name'] = medals_data['last_name'].str.capitalize()
medals_data.head(100)
# Out:
#    discipline_title     slug_game                 event_title event_gender  \
# 0           Curling  beijing-2022               Mixed Doubles        Mixed
# 1           Curling  beijing-2022               Mixed Doubles        Mixed
# 2           Curling  beijing-2022               Mixed Doubles        Mixed
# 3           Curling  beijing-2022               Mixed Doubles        Mixed
# 4           Curling  beijing-2022               Mixed Doubles        Mixed
# ..              ...           ...                         ...          ...
# 95        Snowboard  beijing-2022   Women's Snowboard Big Air        Women
# 96        Snowboard  beijing-2022       Men's Snowboard Cross          Men
# 97        Snowboard  beijing-2022       Men's Snowboard Cross          Men
# 98        Snowboard  beijing-2022       Men's Snowboard Cross          Men
# 99        Snowboard  beijing-2022  Men's Snowboard Slopestyle          Men
#
#    medal_type participant_type participant_title  \
# 0        GOLD         GameTeam             Italy
# 1        GOLD         GameTeam             Italy
# 2      SILVER         GameTeam            Norway
# 3      SILVER         GameTeam            Norway
# 4      BRONZE         GameTeam            Sweden
# ..        ...              ...               ...
# 95       GOLD          Athlete               NaN
# 96     BRONZE          Athlete               NaN
# 97     SILVER          Athlete               NaN
# 98       GOLD          Athlete               NaN
# 99       GOLD          Athlete               NaN
#
#                                               athlete_url  \
# 0   https://olympics.com/en/athletes/stefania-constantini
# 1           https://olympics.com/en/athletes/amos-mosaner
# 2       https://olympics.com/en/athletes/kristin-skaslien
# 3     https://olympics.com/en/athletes/magnus-nedregotten
# 4          https://olympics.com/en/athletes/almida-de-val
# ..                                                    ...
# 95           https://olympics.com/en/athletes/anna-gasser
# 96         https://olympics.com/en/athletes/omar-visintin
# 97         https://olympics.com/en/athletes/eliot-grondin
# 98  https://olympics.com/en/athletes/alessandro-haemmerle
# 99                https://olympics.com/en/athletes/parrot
#
#        athlete_full_name country_name country_code country_3_letter_code  \
# 0   Stefania CONSTANTINI        Italy           IT                   ITA
# 1           Amos MOSANER        Italy           IT                   ITA
# 2       Kristin SKASLIEN       Norway           NO                   NOR
# 3     Magnus NEDREGOTTEN       Norway           NO                   NOR
# 4          Almida DE VAL       Sweden           SE                   SWE
# ..                   ...          ...          ...                   ...
# 95           Anna GASSER      Austria           AT                   AUT
# 96         Omar VISINTIN        Italy           IT                   ITA
# 97         Eliot GRONDIN       Canada           CA                   CAN
# 98  Alessandro HAEMMERLE      Austria           AT                   AUT
# 99            Max PARROT       Canada           CA                   CAN
#
#     first_name    last_name
# 0     Stefania  Constantini
# 1         Amos      Mosaner
# 2      Kristin     Skaslien
# 3       Magnus  Nedregotten
# 4       Almida       De val
# ..         ...          ...
# 95        Anna       Gasser
# 96        Omar     Visintin
# 97       Eliot      Grondin
# 98  Alessandro    Haemmerle
# 99         Max       Parrot
#
# [100 rows x 14 columns]

# %%
# Replace missing values with an empty string
medals_data['athlete_full_name'] = medals_data['athlete_full_name'].fillna('')

# Splitting last name into components
medals_data[['first_name', 'last_name']] = medals_data["athlete_full_name"].apply(lambda x: pd.Series(str(x).split(' ', 1)))

# Capitalizing each component of the last name
medals_data['last_name'] = medals_data['last_name'].apply(lambda x: ' '.join([part.capitalize() for part in str(x).split()]))

# Capitalizing first name
medals_data['first_name'] = medals_data['first_name'].str.capitalize()

medals_data.head()
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 2          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 3          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 4          Curling  beijing-2022  Mixed Doubles        Mixed     BRONZE
#
#   participant_type participant_title  \
# 0         GameTeam             Italy
# 1         GameTeam             Italy
# 2         GameTeam            Norway
# 3         GameTeam            Norway
# 4         GameTeam            Sweden
#
#                                              athlete_url  \
# 0  https://olympics.com/en/athletes/stefania-constantini
# 1          https://olympics.com/en/athletes/amos-mosaner
# 2      https://olympics.com/en/athletes/kristin-skaslien
# 3    https://olympics.com/en/athletes/magnus-nedregotten
# 4         https://olympics.com/en/athletes/almida-de-val
#
#       athlete_full_name country_name country_code country_3_letter_code  \
# 0  Stefania CONSTANTINI        Italy           IT                   ITA
# 1          Amos MOSANER        Italy           IT                   ITA
# 2      Kristin SKASLIEN       Norway           NO                   NOR
# 3    Magnus NEDREGOTTEN       Norway           NO                   NOR
# 4         Almida DE VAL       Sweden           SE                   SWE
#
#   first_name    last_name
# 0   Stefania  Constantini
# 1       Amos      Mosaner
# 2    Kristin     Skaslien
# 3     Magnus  Nedregotten
# 4     Almida       De Val

# %%
# Function to split and capitalize last name
def split_and_capitalize_last_name(full_name):
    if isinstance(full_name, str):
        # Splitting the full name into parts
        name_parts = full_name.split(' ')
        if len(name_parts) > 1:
            # Captializing the last name parts
            last_name_parts = [part.capitalize() for part in name_parts[1:]]  # Consider all parts after the first
            return ' '.join(last_name_parts)
        elif len(name_parts) > 1:
            # Captializing the last name parts
            last_name_parts = [part.capitalize() for part in name_parts[1:]]  # Consider all parts after the first
            return '-'.join(last_name_parts)
        elif len(name_parts) == 1:
            # Capitalize single-word last name
            return name_parts[0].capitalize()  
    return ''

# Apply the function to extract last names
medals_data['last_name'] = medals_data['athlete_full_name'].apply(split_and_capitalize_last_name)

medals_data.head(50)
# Out:
#     discipline_title     slug_game                 event_title event_gender  \
# 0            Curling  beijing-2022               Mixed Doubles        Mixed
# 1            Curling  beijing-2022               Mixed Doubles        Mixed
# 2            Curling  beijing-2022               Mixed Doubles        Mixed
# 3            Curling  beijing-2022               Mixed Doubles        Mixed
# 4            Curling  beijing-2022               Mixed Doubles        Mixed
# 5            Curling  beijing-2022               Mixed Doubles        Mixed
# 6            Curling  beijing-2022                       Women        Women
# 7            Curling  beijing-2022                       Women        Women
# 8            Curling  beijing-2022                       Women        Women
# 9            Curling  beijing-2022                         Men          Men
# 10           Curling  beijing-2022                         Men          Men
# 11           Curling  beijing-2022                         Men          Men
# 12  Freestyle Skiing  beijing-2022                Men's Moguls          Men
# 13  Freestyle Skiing  beijing-2022                Men's Moguls          Men
# 14  Freestyle Skiing  beijing-2022                Men's Moguls          Men
# 15  Freestyle Skiing  beijing-2022      Men's Freeski Halfpipe          Men
# 16  Freestyle Skiing  beijing-2022      Men's Freeski Halfpipe          Men
# 17  Freestyle Skiing  beijing-2022      Men's Freeski Halfpipe          Men
# 18  Freestyle Skiing  beijing-2022       Men's Freeski Big Air          Men
# 19  Freestyle Skiing  beijing-2022       Men's Freeski Big Air          Men
# 20  Freestyle Skiing  beijing-2022       Men's Freeski Big Air          Men
# 21  Freestyle Skiing  beijing-2022             Men's Ski Cross          Men
# 22  Freestyle Skiing  beijing-2022             Men's Ski Cross          Men
# 23  Freestyle Skiing  beijing-2022             Men's Ski Cross          Men
# 24  Freestyle Skiing  beijing-2022     Women's Freeski Big Air        Women
# 25  Freestyle Skiing  beijing-2022     Women's Freeski Big Air        Women
# 26  Freestyle Skiing  beijing-2022     Women's Freeski Big Air        Women
# 27  Freestyle Skiing  beijing-2022              Women's Moguls        Women
# 28  Freestyle Skiing  beijing-2022              Women's Moguls        Women
# 29  Freestyle Skiing  beijing-2022              Women's Moguls        Women
# 30  Freestyle Skiing  beijing-2022          Mixed Team Aerials        Mixed
# 31  Freestyle Skiing  beijing-2022          Mixed Team Aerials        Mixed
# 32  Freestyle Skiing  beijing-2022          Mixed Team Aerials        Mixed
# 33  Freestyle Skiing  beijing-2022           Women's Ski Cross        Women
# 34  Freestyle Skiing  beijing-2022           Women's Ski Cross        Women
# 35  Freestyle Skiing  beijing-2022           Women's Ski Cross        Women
# 36  Freestyle Skiing  beijing-2022               Men's Aerials          Men
# 37  Freestyle Skiing  beijing-2022               Men's Aerials          Men
# 38  Freestyle Skiing  beijing-2022               Men's Aerials          Men
# 39  Freestyle Skiing  beijing-2022             Women's Aerials        Women
# 40  Freestyle Skiing  beijing-2022             Women's Aerials        Women
# 41  Freestyle Skiing  beijing-2022             Women's Aerials        Women
# 42  Freestyle Skiing  beijing-2022    Women's Freeski Halfpipe        Women
# 43  Freestyle Skiing  beijing-2022    Women's Freeski Halfpipe        Women
# 44  Freestyle Skiing  beijing-2022    Women's Freeski Halfpipe        Women
# 45  Freestyle Skiing  beijing-2022  Women's Freeski Slopestyle        Women
# 46  Freestyle Skiing  beijing-2022  Women's Freeski Slopestyle        Women
# 47  Freestyle Skiing  beijing-2022  Women's Freeski Slopestyle        Women
# 48  Freestyle Skiing  beijing-2022    Men's Freeski Slopestyle          Men
# 49  Freestyle Skiing  beijing-2022    Men's Freeski Slopestyle          Men
#
#    medal_type participant_type participant_title  \
# 0        GOLD         GameTeam             Italy
# 1        GOLD         GameTeam             Italy
# 2      SILVER         GameTeam            Norway
# 3      SILVER         GameTeam            Norway
# 4      BRONZE         GameTeam            Sweden
# 5      BRONZE         GameTeam            Sweden
# 6        GOLD         GameTeam     Great Britain
# 7      SILVER         GameTeam             Japan
# 8      BRONZE         GameTeam            Sweden
# 9        GOLD         GameTeam            Sweden
# 10     SILVER         GameTeam     Great Britain
# 11     BRONZE         GameTeam            Canada
# 12     SILVER          Athlete               NaN
# 13       GOLD          Athlete               NaN
# 14     BRONZE          Athlete               NaN
# 15       GOLD          Athlete               NaN
# 16     SILVER          Athlete               NaN
# 17     BRONZE          Athlete               NaN
# 18     BRONZE          Athlete               NaN
# 19       GOLD          Athlete               NaN
# 20     SILVER          Athlete               NaN
# 21     BRONZE          Athlete               NaN
# 22     SILVER          Athlete               NaN
# 23       GOLD          Athlete               NaN
# 24     BRONZE          Athlete               NaN
# 25       GOLD          Athlete               NaN
# 26     SILVER          Athlete               NaN
# 27     SILVER          Athlete               NaN
# 28       GOLD          Athlete               NaN
# 29     BRONZE          Athlete               NaN
# 30       GOLD         GameTeam     United States
# 31     SILVER         GameTeam             China
# 32     BRONZE         GameTeam            Canada
# 33     SILVER          Athlete               NaN
# 34       GOLD          Athlete               NaN
# 35     BRONZE          Athlete               NaN
# 36     BRONZE          Athlete               NaN
# 37       GOLD          Athlete               NaN
# 38     SILVER          Athlete               NaN
# 39     SILVER          Athlete               NaN
# 40       GOLD          Athlete               NaN
# 41     BRONZE          Athlete               NaN
# 42     SILVER          Athlete               NaN
# 43       GOLD          Athlete               NaN
# 44     BRONZE          Athlete               NaN
# 45     SILVER          Athlete               NaN
# 46       GOLD          Athlete               NaN
# 47     BRONZE          Athlete               NaN
# 48     SILVER          Athlete               NaN
# 49     BRONZE          Athlete               NaN
#
#                                               athlete_url  \
# 0   https://olympics.com/en/athletes/stefania-constantini
# 1           https://olympics.com/en/athletes/amos-mosaner
# 2       https://olympics.com/en/athletes/kristin-skaslien
# 3     https://olympics.com/en/athletes/magnus-nedregotten
# 4          https://olympics.com/en/athletes/almida-de-val
# 5         https://olympics.com/en/athletes/oskar-eriksson
# 6                                                     NaN
# 7                                                     NaN
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12      https://olympics.com/en/athletes/mikael-kingsbury
# 13              https://olympics.com/en/athletes/wallberg
# 14       https://olympics.com/en/athletes/ikuma-horishima
# 15         https://olympics.com/en/athletes/nico-porteous
# 16            https://olympics.com/en/athletes/david-wise
# 17         https://olympics.com/en/athletes/alex-ferreira
# 18        https://olympics.com/en/athletes/henrik-harlaut
# 19             https://olympics.com/en/athletes/birk-ruud
# 20       https://olympics.com/en/athletes/colby-stevenson
# 21       https://olympics.com/en/athletes/sergey-ridzik-1
# 22             https://olympics.com/en/athletes/alex-fiva
# 23            https://olympics.com/en/athletes/ryan-regez
# 24      https://olympics.com/en/athletes/mathilde-gremaud
# 25      https://olympics.com/en/athletes/gu-ailing-eileen
# 26           https://olympics.com/en/athletes/tess-ledeux
# 27                  https://olympics.com/en/athletes/kauf
# 28               https://olympics.com/en/athletes/anthony
# 29   https://olympics.com/en/athletes/anastasiia-smirnova
# 30                                                    NaN
# 31                                                    NaN
# 32                                                    NaN
# 33     https://olympics.com/en/athletes/marielle-thompson
# 34       https://olympics.com/en/athletes/sandra-naeslund
# 35         https://olympics.com/en/athletes/daniela-maier
# 36            https://olympics.com/en/athletes/ilia-burov
# 37            https://olympics.com/en/athletes/guangpu-qi
# 38   https://olympics.com/en/athletes/oleksandr-abramenko
# 39         https://olympics.com/en/athletes/hanna-huskova
# 40            https://olympics.com/en/athletes/mengtao-xu
# 41            https://olympics.com/en/athletes/megan-nick
# 42         https://olympics.com/en/athletes/cassie-sharpe
# 43      https://olympics.com/en/athletes/gu-ailing-eileen
# 44         https://olympics.com/en/athletes/rachel-karker
# 45      https://olympics.com/en/athletes/gu-ailing-eileen
# 46      https://olympics.com/en/athletes/mathilde-gremaud
# 47         https://olympics.com/en/athletes/kelly-sildaru
# 48      https://olympics.com/en/athletes/nicholas-goepper
# 49         https://olympics.com/en/athletes/jesper-tjader
#
#        athlete_full_name                country_name country_code  \
# 0   Stefania CONSTANTINI                       Italy           IT
# 1           Amos MOSANER                       Italy           IT
# 2       Kristin SKASLIEN                      Norway           NO
# 3     Magnus NEDREGOTTEN                      Norway           NO
# 4          Almida DE VAL                      Sweden           SE
# 5         Oskar ERIKSSON                      Sweden           SE
# 6                                      Great Britain           GB
# 7                                              Japan           JP
# 8                                             Sweden           SE
# 9                                             Sweden           SE
# 10                                     Great Britain           GB
# 11                                            Canada           CA
# 12      Mikael KINGSBURY                      Canada           CA
# 13       Walter WALLBERG                      Sweden           SE
# 14       Ikuma HORISHIMA                       Japan           JP
# 15         Nico PORTEOUS                 New Zealand           NZ
# 16            David WISE    United States of America           US
# 17         Alex FERREIRA    United States of America           US
# 18        Henrik HARLAUT                      Sweden           SE
# 19             Birk RUUD                      Norway           NO
# 20       Colby STEVENSON    United States of America           US
# 21         Sergey RIDZIK                         ROC          ROC
# 22             Alex FIVA                 Switzerland           CH
# 23            Ryan REGEZ                 Switzerland           CH
# 24      Mathilde GREMAUD                 Switzerland           CH
# 25      Ailing Eileen GU  People's Republic of China           CN
# 26           Tess LEDEUX                      France           FR
# 27           Jaelin KAUF    United States of America           US
# 28        Jakara ANTHONY                   Australia           AU
# 29   Anastasiia SMIRNOVA                         ROC          ROC
# 30                          United States of America           US
# 31                        People's Republic of China           CN
# 32                                            Canada           CA
# 33     Marielle THOMPSON                      Canada           CA
# 34       Sandra NAESLUND                      Sweden           SE
# 35         Daniela MAIER                     Germany           DE
# 36            Ilia BUROV                         ROC          ROC
# 37            Guangpu QI  People's Republic of China           CN
# 38   Oleksandr ABRAMENKO                     Ukraine           UA
# 39         Hanna HUSKOVA                     Belarus           BY
# 40            Mengtao XU  People's Republic of China           CN
# 41            Megan NICK    United States of America           US
# 42         Cassie SHARPE                      Canada           CA
# 43      Ailing Eileen GU  People's Republic of China           CN
# 44         Rachel KARKER                      Canada           CA
# 45      Ailing Eileen GU  People's Republic of China           CN
# 46      Mathilde GREMAUD                 Switzerland           CH
# 47         Kelly SILDARU                     Estonia           EE
# 48      Nicholas GOEPPER    United States of America           US
# 49         Jesper TJADER                      Sweden           SE
#
#    country_3_letter_code  first_name    last_name
# 0                    ITA    Stefania  Constantini
# 1                    ITA        Amos      Mosaner
# 2                    NOR     Kristin     Skaslien
# 3                    NOR      Magnus  Nedregotten
# 4                    SWE      Almida       De Val
# 5                    SWE       Oskar     Eriksson
# 6                    GBR
# 7                    JPN
# 8                    SWE
# 9                    SWE
# 10                   GBR
# 11                   CAN
# 12                   CAN      Mikael    Kingsbury
# 13                   SWE      Walter     Wallberg
# 14                   JPN       Ikuma    Horishima
# 15                   NZL        Nico     Porteous
# 16                   USA       David         Wise
# 17                   USA        Alex     Ferreira
# 18                   SWE      Henrik      Harlaut
# 19                   NOR        Birk         Ruud
# 20                   USA       Colby    Stevenson
# 21                   ROC      Sergey       Ridzik
# 22                   SUI        Alex         Fiva
# 23                   SUI        Ryan        Regez
# 24                   SUI    Mathilde      Gremaud
# 25                   CHN      Ailing    Eileen Gu
# 26                   FRA        Tess       Ledeux
# 27                   USA      Jaelin         Kauf
# 28                   AUS      Jakara      Anthony
# 29                   ROC  Anastasiia     Smirnova
# 30                   USA
# 31                   CHN
# 32                   CAN
# 33                   CAN    Marielle     Thompson
# 34                   SWE      Sandra     Naeslund
# 35                   GER     Daniela        Maier
# 36                   ROC        Ilia        Burov
# 37                   CHN     Guangpu           Qi
# 38                   UKR   Oleksandr    Abramenko
# 39                   BLR       Hanna      Huskova
# 40                   CHN     Mengtao           Xu
# 41                   USA       Megan         Nick
# 42                   CAN      Cassie       Sharpe
# 43                   CHN      Ailing    Eileen Gu
# 44                   CAN      Rachel       Karker
# 45                   CHN      Ailing    Eileen Gu
# 46                   SUI    Mathilde      Gremaud
# 47                   EST       Kelly      Sildaru
# 48                   USA    Nicholas      Goepper
# 49                   SWE      Jesper       Tjader

# %%
medals_data.columns
# Out:
# Index(['discipline_title', 'slug_game', 'event_title', 'event_gender',
#        'medal_type', 'participant_type', 'participant_title', 'athlete_url',
#        'athlete_full_name', 'country_name', 'country_code',
#        'country_3_letter_code', 'first_name', 'last_name'],
#       dtype='object')

# %%
# Drop rows where 'athlete_full_name' column is an empty string
medals_data = medals_data[medals_data['athlete_full_name'] != '']

# Now you can apply the function to extract last names
medals_data['last_name'] = medals_data['athlete_full_name'].apply(split_and_capitalize_last_name)


medals_data.head()
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 2          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 3          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 4          Curling  beijing-2022  Mixed Doubles        Mixed     BRONZE
#
#   participant_type participant_title  \
# 0         GameTeam             Italy
# 1         GameTeam             Italy
# 2         GameTeam            Norway
# 3         GameTeam            Norway
# 4         GameTeam            Sweden
#
#                                              athlete_url  \
# 0  https://olympics.com/en/athletes/stefania-constantini
# 1          https://olympics.com/en/athletes/amos-mosaner
# 2      https://olympics.com/en/athletes/kristin-skaslien
# 3    https://olympics.com/en/athletes/magnus-nedregotten
# 4         https://olympics.com/en/athletes/almida-de-val
#
#       athlete_full_name country_name country_code country_3_letter_code  \
# 0  Stefania CONSTANTINI        Italy           IT                   ITA
# 1          Amos MOSANER        Italy           IT                   ITA
# 2      Kristin SKASLIEN       Norway           NO                   NOR
# 3    Magnus NEDREGOTTEN       Norway           NO                   NOR
# 4         Almida DE VAL       Sweden           SE                   SWE
#
#   first_name    last_name
# 0   Stefania  Constantini
# 1       Amos      Mosaner
# 2    Kristin     Skaslien
# 3     Magnus  Nedregotten
# 4     Almida       De Val

# %%
# Drop unwanted columns  
medals_data = medals_data.drop(['athlete_full_name', 'country_code', 'participant_title'], axis=1)

medals_data.head()
# Out:
#   discipline_title     slug_game    event_title event_gender medal_type  \
# 0          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 1          Curling  beijing-2022  Mixed Doubles        Mixed       GOLD
# 2          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 3          Curling  beijing-2022  Mixed Doubles        Mixed     SILVER
# 4          Curling  beijing-2022  Mixed Doubles        Mixed     BRONZE
#
#   participant_type                                            athlete_url  \
# 0         GameTeam  https://olympics.com/en/athletes/stefania-constantini
# 1         GameTeam          https://olympics.com/en/athletes/amos-mosaner
# 2         GameTeam      https://olympics.com/en/athletes/kristin-skaslien
# 3         GameTeam    https://olympics.com/en/athletes/magnus-nedregotten
# 4         GameTeam         https://olympics.com/en/athletes/almida-de-val
#
#   country_name country_3_letter_code first_name    last_name
# 0        Italy                   ITA   Stefania  Constantini
# 1        Italy                   ITA       Amos      Mosaner
# 2       Norway                   NOR    Kristin     Skaslien
# 3       Norway                   NOR     Magnus  Nedregotten
# 4       Sweden                   SWE     Almida       De Val
