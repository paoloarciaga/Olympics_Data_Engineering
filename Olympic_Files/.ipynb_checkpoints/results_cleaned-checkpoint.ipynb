# %%
# Import dependencies
import pandas as pd
import numpy as np
from pathlib import Path
pd.set_option('max_colwidth', 400)

# %%
Olympic_games_olympic_results_data = Path("Olympic_Files/olympic_results.csv")

# Read medals and results Data File and store into Pandas DataFrames
results_data = pd.read_csv(Olympic_games_olympic_results_data)
results_data.head()
# Out:
#   discipline_title    event_title     slug_game participant_type medal_type  \
# 0          Curling  Mixed Doubles  beijing-2022         GameTeam       GOLD
# 1          Curling  Mixed Doubles  beijing-2022         GameTeam     SILVER
# 2          Curling  Mixed Doubles  beijing-2022         GameTeam     BRONZE
# 3          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 4          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
#
#                                                                                                                                                      athletes  \
# 0      [('Stefania CONSTANTINI', 'https://olympics.com/en/athletes/stefania-constantini'), ('Amos MOSANER', 'https://olympics.com/en/athletes/amos-mosaner')]
# 1  [('Kristin SKASLIEN', 'https://olympics.com/en/athletes/kristin-skaslien'), ('Magnus NEDREGOTTEN', 'https://olympics.com/en/athletes/magnus-nedregotten')]
# 2                [('Almida DE VAL', 'https://olympics.com/en/athletes/almida-de-val'), ('Oskar ERIKSSON', 'https://olympics.com/en/athletes/oskar-eriksson')]
# 3                    [('Jennifer DODDS', 'https://olympics.com/en/athletes/jennifer-dodds'), ('Bruce MOUAT', 'https://olympics.com/en/athletes/bruce-mouat')]
# 4                        [('Rachel HOMAN', 'https://olympics.com/en/athletes/rachel-homan'), ('John MORRIS', 'https://olympics.com/en/athletes/john-morris')]
#
#   rank_equal rank_position   country_name country_code country_3_letter_code  \
# 0      False             1          Italy           IT                   ITA
# 1      False             2         Norway           NO                   NOR
# 2      False             3         Sweden           SE                   SWE
# 3      False             4  Great Britain           GB                   GBR
# 4      False             5         Canada           CA                   CAN
#
#   athlete_url athlete_full_name value_unit value_type
# 0         NaN               NaN        NaN        NaN
# 1         NaN               NaN        NaN        NaN
# 2         NaN               NaN        NaN        NaN
# 3         NaN               NaN        NaN        NaN
# 4         NaN               NaN        NaN        NaN

# %%
results_data.columns
# Out:
# Index(['discipline_title', 'event_title', 'slug_game', 'participant_type',
#        'medal_type', 'athletes', 'rank_equal', 'rank_position', 'country_name',
#        'country_code', 'country_3_letter_code', 'athlete_url',
#        'athlete_full_name', 'value_unit', 'value_type'],
#       dtype='object')

# %%
# Count NaN values in the 'athlete_full_name' column
nan_count = results_data['athlete_full_name'].isna().sum()

print("Number of NaN values in 'athlete_full_name' column:", nan_count)
# Out:
# Number of NaN values in 'athlete_full_name' column: 21158

# %%
# Replace missing values with an empty string
results_data['athlete_full_name'] = results_data['athlete_full_name'].fillna('')

# Splitting last name into components
results_data[['first_name', 'last_name']] = results_data["athlete_full_name"].apply(lambda x: pd.Series(str(x).split(' ', 1)))

# Capitalizing each component of the last name
results_data['last_name'] = results_data['last_name'].apply(lambda x: ' '.join([part.capitalize() for part in str(x).split()]))

# Capitalizing first name
results_data['first_name'] = results_data['first_name'].str.capitalize()

results_data.head()
# Out:
#   discipline_title    event_title     slug_game participant_type medal_type  \
# 0          Curling  Mixed Doubles  beijing-2022         GameTeam       GOLD
# 1          Curling  Mixed Doubles  beijing-2022         GameTeam     SILVER
# 2          Curling  Mixed Doubles  beijing-2022         GameTeam     BRONZE
# 3          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 4          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
#
#                                                                                                                                                      athletes  \
# 0      [('Stefania CONSTANTINI', 'https://olympics.com/en/athletes/stefania-constantini'), ('Amos MOSANER', 'https://olympics.com/en/athletes/amos-mosaner')]
# 1  [('Kristin SKASLIEN', 'https://olympics.com/en/athletes/kristin-skaslien'), ('Magnus NEDREGOTTEN', 'https://olympics.com/en/athletes/magnus-nedregotten')]
# 2                [('Almida DE VAL', 'https://olympics.com/en/athletes/almida-de-val'), ('Oskar ERIKSSON', 'https://olympics.com/en/athletes/oskar-eriksson')]
# 3                    [('Jennifer DODDS', 'https://olympics.com/en/athletes/jennifer-dodds'), ('Bruce MOUAT', 'https://olympics.com/en/athletes/bruce-mouat')]
# 4                        [('Rachel HOMAN', 'https://olympics.com/en/athletes/rachel-homan'), ('John MORRIS', 'https://olympics.com/en/athletes/john-morris')]
#
#   rank_equal rank_position   country_name country_code country_3_letter_code  \
# 0      False             1          Italy           IT                   ITA
# 1      False             2         Norway           NO                   NOR
# 2      False             3         Sweden           SE                   SWE
# 3      False             4  Great Britain           GB                   GBR
# 4      False             5         Canada           CA                   CAN
#
#   athlete_url athlete_full_name value_unit value_type first_name last_name
# 0         NaN                          NaN        NaN                  Nan
# 1         NaN                          NaN        NaN                  Nan
# 2         NaN                          NaN        NaN                  Nan
# 3         NaN                          NaN        NaN                  Nan
# 4         NaN                          NaN        NaN                  Nan

# %%
def split_and_capitalize_last_name(full_name):
    if isinstance(full_name, str):
        # Splitting the full name into parts
        name_parts = full_name.split(' ')
        # Captializing the last name parts
        if len(name_parts) > 1:
            last_name_parts = []
            for part in name_parts[1:]:
                if '-' in part:
                    hyphen_parts = part.split('-')
                    capitalized_parts = [p.capitalize() for p in hyphen_parts]
                    last_name_parts.extend(capitalized_parts)
                else:
                    last_name_parts.append(part.capitalize())
            return ' '.join(last_name_parts)

# Test the function with a sample value
print(split_and_capitalize_last_name("Cooper Woods-topalovic"))
print(split_and_capitalize_last_name("Almida De val"))
# Out:
# Woods Topalovic
# De Val

# %%
def split_and_capitalize_last_name(full_name):
    if isinstance(full_name, str):
        # Splitting the full name into parts
        name_parts = full_name.split(' ')
        # Captializing the last name parts
        if len(name_parts) > 1:
            last_name_parts = []
            for part in name_parts[1:]:
                if '-' in part:
                    hyphen_parts = part.split('-')
                    capitalized_parts = [p.capitalize() for p in hyphen_parts]
                    last_name_parts.extend(capitalized_parts)
                else:
                    last_name_parts.append(part.capitalize())
            return ' '.join(last_name_parts)

# Test the function with a sample value
print(split_and_capitalize_last_name("Cooper Woods-topalovic"))
print(split_and_capitalize_last_name("Almida De val"))

results_data.head()
# Out:
# Woods Topalovic
# De Val
#   discipline_title    event_title     slug_game participant_type medal_type  \
# 0          Curling  Mixed Doubles  beijing-2022         GameTeam       GOLD
# 1          Curling  Mixed Doubles  beijing-2022         GameTeam     SILVER
# 2          Curling  Mixed Doubles  beijing-2022         GameTeam     BRONZE
# 3          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 4          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
#
#                                                                                                                                                      athletes  \
# 0      [('Stefania CONSTANTINI', 'https://olympics.com/en/athletes/stefania-constantini'), ('Amos MOSANER', 'https://olympics.com/en/athletes/amos-mosaner')]
# 1  [('Kristin SKASLIEN', 'https://olympics.com/en/athletes/kristin-skaslien'), ('Magnus NEDREGOTTEN', 'https://olympics.com/en/athletes/magnus-nedregotten')]
# 2                [('Almida DE VAL', 'https://olympics.com/en/athletes/almida-de-val'), ('Oskar ERIKSSON', 'https://olympics.com/en/athletes/oskar-eriksson')]
# 3                    [('Jennifer DODDS', 'https://olympics.com/en/athletes/jennifer-dodds'), ('Bruce MOUAT', 'https://olympics.com/en/athletes/bruce-mouat')]
# 4                        [('Rachel HOMAN', 'https://olympics.com/en/athletes/rachel-homan'), ('John MORRIS', 'https://olympics.com/en/athletes/john-morris')]
#
#   rank_equal rank_position   country_name country_code country_3_letter_code  \
# 0      False             1          Italy           IT                   ITA
# 1      False             2         Norway           NO                   NOR
# 2      False             3         Sweden           SE                   SWE
# 3      False             4  Great Britain           GB                   GBR
# 4      False             5         Canada           CA                   CAN
#
#   athlete_url athlete_full_name value_unit value_type first_name last_name
# 0         NaN                          NaN        NaN                  Nan
# 1         NaN                          NaN        NaN                  Nan
# 2         NaN                          NaN        NaN                  Nan
# 3         NaN                          NaN        NaN                  Nan
# 4         NaN                          NaN        NaN                  Nan

# %%
results_data.drop('country_code', axis=1, inplace=True)
results_data.head()
# Out:
#   discipline_title    event_title     slug_game participant_type medal_type  \
# 0          Curling  Mixed Doubles  beijing-2022         GameTeam       GOLD
# 1          Curling  Mixed Doubles  beijing-2022         GameTeam     SILVER
# 2          Curling  Mixed Doubles  beijing-2022         GameTeam     BRONZE
# 3          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 4          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
#
#                                                                                                                                                      athletes  \
# 0      [('Stefania CONSTANTINI', 'https://olympics.com/en/athletes/stefania-constantini'), ('Amos MOSANER', 'https://olympics.com/en/athletes/amos-mosaner')]
# 1  [('Kristin SKASLIEN', 'https://olympics.com/en/athletes/kristin-skaslien'), ('Magnus NEDREGOTTEN', 'https://olympics.com/en/athletes/magnus-nedregotten')]
# 2                [('Almida DE VAL', 'https://olympics.com/en/athletes/almida-de-val'), ('Oskar ERIKSSON', 'https://olympics.com/en/athletes/oskar-eriksson')]
# 3                    [('Jennifer DODDS', 'https://olympics.com/en/athletes/jennifer-dodds'), ('Bruce MOUAT', 'https://olympics.com/en/athletes/bruce-mouat')]
# 4                        [('Rachel HOMAN', 'https://olympics.com/en/athletes/rachel-homan'), ('John MORRIS', 'https://olympics.com/en/athletes/john-morris')]
#
#   rank_equal rank_position   country_name country_3_letter_code athlete_url  \
# 0      False             1          Italy                   ITA         NaN
# 1      False             2         Norway                   NOR         NaN
# 2      False             3         Sweden                   SWE         NaN
# 3      False             4  Great Britain                   GBR         NaN
# 4      False             5         Canada                   CAN         NaN
#
#   athlete_full_name value_unit value_type first_name last_name
# 0                          NaN        NaN                  Nan
# 1                          NaN        NaN                  Nan
# 2                          NaN        NaN                  Nan
# 3                          NaN        NaN                  Nan
# 4                          NaN        NaN                  Nan

# %%
# Fill missing values with empty string
results_data['athletes'].fillna('', inplace=True)

# Initialize lists to store extracted data
athlete_data = []

# Iterate over each row in the DataFrame
for idx, entry in enumerate(results_data['athletes']):
    # Split the string by '), (' to separate each athlete's information
    athlete_info = entry.strip('[]').split("), ('")
    # Extract athlete names and URLs from each entry
    for info in athlete_info:
        # Split each entry by ', ' to separate athlete name and URL
        name_url = info.split("', '")
        # Check if name_url has at least two elements
        if len(name_url) >= 2:
            # Extract athlete name and URL
            athlete_name = name_url[0].strip("('")
            athlete_url = name_url[1].strip("')")
            # Append the extracted data to the list
            athlete_data.append({'First Name': athlete_name.split()[0],
                                  'Last Name': split_and_capitalize_last_name(athlete_name),
                                  'URL': athlete_url,
                                  'participant_type': results_data.iloc[idx]['participant_type']})

# Create a DataFrame from the extracted data
df = pd.DataFrame(athlete_data)

df.head()
# Out:
#   First Name    Last Name  \
# 0   Stefania  Constantini
# 1       Amos      Mosaner
# 2    Kristin     Skaslien
# 3     Magnus  Nedregotten
# 4     Almida       De Val
#
#                                                      URL participant_type
# 0  https://olympics.com/en/athletes/stefania-constantini         GameTeam
# 1          https://olympics.com/en/athletes/amos-mosaner         GameTeam
# 2      https://olympics.com/en/athletes/kristin-skaslien         GameTeam
# 3    https://olympics.com/en/athletes/magnus-nedregotten         GameTeam
# 4         https://olympics.com/en/athletes/almida-de-val         GameTeam

# %%
import re

# Assuming results_data is a Pandas DataFrame
athlete_data_list = []

# Iterate over each string representation of list of tuples
for athlete_list_str in results_data['athletes']:
    # Handle empty strings
    if not athlete_list_str.strip():
        continue
    
    # Split the string into tuples
    athlete_list = athlete_list_str.split("), (")
    
    # Remove leading and trailing brackets for the first and last tuples
    if len(athlete_list) > 0:
        athlete_list[0] = athlete_list[0].lstrip("[(")
    if len(athlete_list) > 1:
        athlete_list[-1] = athlete_list[-1].rstrip(")]")
    
    # Iterate over each tuple in the list
    for athlete_data_str in athlete_list:
        # Try to match patterns where name and URL are separated by different delimiters
        match = re.match(r"['\"]([^'\"]*)['\"](?:, (['\"][^'\"]*['\"]))?", athlete_data_str)
        if match:
            athlete_name = match.group(1)
            athlete_url = match.group(2)
            
            # Split the name into first and last name
            name_parts = athlete_name.split(' ')
            if len(name_parts) >= 2:
                first_name = name_parts[0]
                last_name = ' '.join(name_parts[1:])
            else:
                # If name doesn't have both first and last name, use full name as first name
                first_name = athlete_name
                last_name = ""
            
            # If URL is missing, set it to None
            if athlete_url:
                athlete_url = athlete_url.strip('"')
            else:
                athlete_url = None
            
            athlete_data_list.append({
                'First Name': first_name,
                'Last Name': last_name,
                'URL': athlete_url
            })
        else:
            print(f"Failed to extract name and URL from: {athlete_data_str}")

# Convert the list of dictionaries into a DataFrame
athlete_df = pd.DataFrame(athlete_data_list)


athlete_df.head()
# Out:
#   First Name    Last Name  \
# 0   Stefania  CONSTANTINI
# 1       Amos      MOSANER
# 2    Kristin     SKASLIEN
# 3     Magnus  NEDREGOTTEN
# 4     Almida       DE VAL
#
#                                                        URL
# 0  'https://olympics.com/en/athletes/stefania-constantini'
# 1          'https://olympics.com/en/athletes/amos-mosaner'
# 2      'https://olympics.com/en/athletes/kristin-skaslien'
# 3    'https://olympics.com/en/athletes/magnus-nedregotten'
# 4         'https://olympics.com/en/athletes/almida-de-val'

# %%
import ast

# Function to extract athlete information
def separate_athletes(row):
    try:
        athletes_info = row['athletes']
        if athletes_info:
            athlete_info = ast.literal_eval(athletes_info)
            if isinstance(athlete_info, list) and len(athlete_info) >= 2:
                athlete1 = athlete_info[0]
                athlete2 = athlete_info[1]
                athlete1_first_name, athlete1_last_name = athlete1[0].split(maxsplit=1)
                athlete2_first_name, athlete2_last_name = athlete2[0].split(maxsplit=1)
                return pd.Series([
                    athlete1_first_name, athlete1_last_name, athlete1[1], 
                    athlete2_first_name, athlete2_last_name, athlete2[1]
                ])
            else:
                return pd.Series([None, None, None, None, None, None])
        else:
            return pd.Series([None, None, None, None, None, None])
    except Exception as e:
        print(f"Error processing row: {row}")
        print(f"Error message: {e}")
        return pd.Series([None, None, None, None, None, None])

# Apply the function to each row
results_data[['athlete1_first_name', 'athlete1_last_name', 'athlete1_url', 
              'athlete2_first_name', 'athlete2_last_name', 'athlete2_url']] = results_data.apply(separate_athletes, axis=1)



results_data.head()
# Out:
#   discipline_title    event_title     slug_game participant_type medal_type  \
# 0          Curling  Mixed Doubles  beijing-2022         GameTeam       GOLD
# 1          Curling  Mixed Doubles  beijing-2022         GameTeam     SILVER
# 2          Curling  Mixed Doubles  beijing-2022         GameTeam     BRONZE
# 3          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 4          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
#
#                                                                                                                                                      athletes  \
# 0      [('Stefania CONSTANTINI', 'https://olympics.com/en/athletes/stefania-constantini'), ('Amos MOSANER', 'https://olympics.com/en/athletes/amos-mosaner')]
# 1  [('Kristin SKASLIEN', 'https://olympics.com/en/athletes/kristin-skaslien'), ('Magnus NEDREGOTTEN', 'https://olympics.com/en/athletes/magnus-nedregotten')]
# 2                [('Almida DE VAL', 'https://olympics.com/en/athletes/almida-de-val'), ('Oskar ERIKSSON', 'https://olympics.com/en/athletes/oskar-eriksson')]
# 3                    [('Jennifer DODDS', 'https://olympics.com/en/athletes/jennifer-dodds'), ('Bruce MOUAT', 'https://olympics.com/en/athletes/bruce-mouat')]
# 4                        [('Rachel HOMAN', 'https://olympics.com/en/athletes/rachel-homan'), ('John MORRIS', 'https://olympics.com/en/athletes/john-morris')]
#
#   rank_equal rank_position   country_name country_3_letter_code  ...  \
# 0      False             1          Italy                   ITA  ...
# 1      False             2         Norway                   NOR  ...
# 2      False             3         Sweden                   SWE  ...
# 3      False             4  Great Britain                   GBR  ...
# 4      False             5         Canada                   CAN  ...
#
#   value_unit value_type first_name last_name athlete1_first_name  \
# 0        NaN        NaN                  Nan            Stefania
# 1        NaN        NaN                  Nan             Kristin
# 2        NaN        NaN                  Nan              Almida
# 3        NaN        NaN                  Nan            Jennifer
# 4        NaN        NaN                  Nan              Rachel
#
#   athlete1_last_name                                           athlete1_url  \
# 0        CONSTANTINI  https://olympics.com/en/athletes/stefania-constantini
# 1           SKASLIEN      https://olympics.com/en/athletes/kristin-skaslien
# 2             DE VAL         https://olympics.com/en/athletes/almida-de-val
# 3              DODDS        https://olympics.com/en/athletes/jennifer-dodds
# 4              HOMAN          https://olympics.com/en/athletes/rachel-homan
#
#   athlete2_first_name athlete2_last_name  \
# 0                Amos            MOSANER
# 1              Magnus        NEDREGOTTEN
# 2               Oskar           ERIKSSON
# 3               Bruce              MOUAT
# 4                John             MORRIS
#
#                                           athlete2_url
# 0        https://olympics.com/en/athletes/amos-mosaner
# 1  https://olympics.com/en/athletes/magnus-nedregotten
# 2      https://olympics.com/en/athletes/oskar-eriksson
# 3         https://olympics.com/en/athletes/bruce-mouat
# 4         https://olympics.com/en/athletes/john-morris
#
# [5 rows x 22 columns]

# %%
def format_last_name(last_name):
    if last_name is None:
        return None
    # Split the last name by hyphen or space if present
    parts = [part.capitalize() for part in last_name.split('-' if '-' in last_name else ' ')]
    # Join the parts to form the formatted last name
    return '-'.join(parts) if '-' in last_name else ' '.join(parts)

# Apply the formatting function to 'athlete1_last_name' and 'athlete2_last_name' columns
results_data['athlete1_last_name'] = results_data['athlete1_last_name'].apply(format_last_name)
results_data['athlete2_last_name'] = results_data['athlete2_last_name'].apply(format_last_name)

results_data.head()
# Out:
#   discipline_title    event_title     slug_game participant_type medal_type  \
# 0          Curling  Mixed Doubles  beijing-2022         GameTeam       GOLD
# 1          Curling  Mixed Doubles  beijing-2022         GameTeam     SILVER
# 2          Curling  Mixed Doubles  beijing-2022         GameTeam     BRONZE
# 3          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 4          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
#
#                                                                                                                                                      athletes  \
# 0      [('Stefania CONSTANTINI', 'https://olympics.com/en/athletes/stefania-constantini'), ('Amos MOSANER', 'https://olympics.com/en/athletes/amos-mosaner')]
# 1  [('Kristin SKASLIEN', 'https://olympics.com/en/athletes/kristin-skaslien'), ('Magnus NEDREGOTTEN', 'https://olympics.com/en/athletes/magnus-nedregotten')]
# 2                [('Almida DE VAL', 'https://olympics.com/en/athletes/almida-de-val'), ('Oskar ERIKSSON', 'https://olympics.com/en/athletes/oskar-eriksson')]
# 3                    [('Jennifer DODDS', 'https://olympics.com/en/athletes/jennifer-dodds'), ('Bruce MOUAT', 'https://olympics.com/en/athletes/bruce-mouat')]
# 4                        [('Rachel HOMAN', 'https://olympics.com/en/athletes/rachel-homan'), ('John MORRIS', 'https://olympics.com/en/athletes/john-morris')]
#
#   rank_equal rank_position   country_name country_3_letter_code  ...  \
# 0      False             1          Italy                   ITA  ...
# 1      False             2         Norway                   NOR  ...
# 2      False             3         Sweden                   SWE  ...
# 3      False             4  Great Britain                   GBR  ...
# 4      False             5         Canada                   CAN  ...
#
#   value_unit value_type first_name last_name athlete1_first_name  \
# 0        NaN        NaN                  Nan            Stefania
# 1        NaN        NaN                  Nan             Kristin
# 2        NaN        NaN                  Nan              Almida
# 3        NaN        NaN                  Nan            Jennifer
# 4        NaN        NaN                  Nan              Rachel
#
#   athlete1_last_name                                           athlete1_url  \
# 0        Constantini  https://olympics.com/en/athletes/stefania-constantini
# 1           Skaslien      https://olympics.com/en/athletes/kristin-skaslien
# 2             De Val         https://olympics.com/en/athletes/almida-de-val
# 3              Dodds        https://olympics.com/en/athletes/jennifer-dodds
# 4              Homan          https://olympics.com/en/athletes/rachel-homan
#
#   athlete2_first_name athlete2_last_name  \
# 0                Amos            Mosaner
# 1              Magnus        Nedregotten
# 2               Oskar           Eriksson
# 3               Bruce              Mouat
# 4                John             Morris
#
#                                           athlete2_url
# 0        https://olympics.com/en/athletes/amos-mosaner
# 1  https://olympics.com/en/athletes/magnus-nedregotten
# 2      https://olympics.com/en/athletes/oskar-eriksson
# 3         https://olympics.com/en/athletes/bruce-mouat
# 4         https://olympics.com/en/athletes/john-morris
#
# [5 rows x 22 columns]

# %%
results_data.drop(['athletes', 'athlete_full_name'], axis=1, inplace=True)
results_data.head()
# Out:
#   discipline_title    event_title     slug_game participant_type medal_type  \
# 0          Curling  Mixed Doubles  beijing-2022         GameTeam       GOLD
# 1          Curling  Mixed Doubles  beijing-2022         GameTeam     SILVER
# 2          Curling  Mixed Doubles  beijing-2022         GameTeam     BRONZE
# 3          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 4          Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
#
#   rank_equal rank_position   country_name country_3_letter_code athlete_url  \
# 0      False             1          Italy                   ITA         NaN
# 1      False             2         Norway                   NOR         NaN
# 2      False             3         Sweden                   SWE         NaN
# 3      False             4  Great Britain                   GBR         NaN
# 4      False             5         Canada                   CAN         NaN
#
#   value_unit value_type first_name last_name athlete1_first_name  \
# 0        NaN        NaN                  Nan            Stefania
# 1        NaN        NaN                  Nan             Kristin
# 2        NaN        NaN                  Nan              Almida
# 3        NaN        NaN                  Nan            Jennifer
# 4        NaN        NaN                  Nan              Rachel
#
#   athlete1_last_name                                           athlete1_url  \
# 0        Constantini  https://olympics.com/en/athletes/stefania-constantini
# 1           Skaslien      https://olympics.com/en/athletes/kristin-skaslien
# 2             De Val         https://olympics.com/en/athletes/almida-de-val
# 3              Dodds        https://olympics.com/en/athletes/jennifer-dodds
# 4              Homan          https://olympics.com/en/athletes/rachel-homan
#
#   athlete2_first_name athlete2_last_name  \
# 0                Amos            Mosaner
# 1              Magnus        Nedregotten
# 2               Oskar           Eriksson
# 3               Bruce              Mouat
# 4                John             Morris
#
#                                           athlete2_url
# 0        https://olympics.com/en/athletes/amos-mosaner
# 1  https://olympics.com/en/athletes/magnus-nedregotten
# 2      https://olympics.com/en/athletes/oskar-eriksson
# 3         https://olympics.com/en/athletes/bruce-mouat
# 4         https://olympics.com/en/athletes/john-morris

# %%
results_data.head(50)
# Out:
#     discipline_title    event_title     slug_game participant_type medal_type  \
# 0            Curling  Mixed Doubles  beijing-2022         GameTeam       GOLD
# 1            Curling  Mixed Doubles  beijing-2022         GameTeam     SILVER
# 2            Curling  Mixed Doubles  beijing-2022         GameTeam     BRONZE
# 3            Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 4            Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 5            Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 6            Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 7            Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 8            Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 9            Curling  Mixed Doubles  beijing-2022         GameTeam        NaN
# 10           Curling          Women  beijing-2022         GameTeam       GOLD
# 11           Curling          Women  beijing-2022         GameTeam     SILVER
# 12           Curling          Women  beijing-2022         GameTeam     BRONZE
# 13           Curling          Women  beijing-2022         GameTeam        NaN
# 14           Curling          Women  beijing-2022         GameTeam        NaN
# 15           Curling          Women  beijing-2022         GameTeam        NaN
# 16           Curling          Women  beijing-2022         GameTeam        NaN
# 17           Curling          Women  beijing-2022         GameTeam        NaN
# 18           Curling          Women  beijing-2022         GameTeam        NaN
# 19           Curling          Women  beijing-2022         GameTeam        NaN
# 20           Curling            Men  beijing-2022         GameTeam       GOLD
# 21           Curling            Men  beijing-2022         GameTeam     SILVER
# 22           Curling            Men  beijing-2022         GameTeam     BRONZE
# 23           Curling            Men  beijing-2022         GameTeam        NaN
# 24           Curling            Men  beijing-2022         GameTeam        NaN
# 25           Curling            Men  beijing-2022         GameTeam        NaN
# 26           Curling            Men  beijing-2022         GameTeam        NaN
# 27           Curling            Men  beijing-2022         GameTeam        NaN
# 28           Curling            Men  beijing-2022         GameTeam        NaN
# 29           Curling            Men  beijing-2022         GameTeam        NaN
# 30  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 31  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 32  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 33  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 34  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 35  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 36  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete     BRONZE
# 37  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 38  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 39  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 40  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 41  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 42  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 43  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 44  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 45  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 46  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete     SILVER
# 47  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
# 48  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete       GOLD
# 49  Freestyle Skiing   Men's Moguls  beijing-2022          Athlete        NaN
#
#    rank_equal rank_position                country_name country_3_letter_code  \
# 0       False             1                       Italy                   ITA
# 1       False             2                      Norway                   NOR
# 2       False             3                      Sweden                   SWE
# 3       False             4               Great Britain                   GBR
# 4       False             5                      Canada                   CAN
# 5       False             6              Czech Republic                   CZE
# 6       False             7                 Switzerland                   SUI
# 7       False             8    United States of America                   USA
# 8       False             9  People's Republic of China                   CHN
# 9       False            10                   Australia                   AUS
# 10      False             1               Great Britain                   GBR
# 11      False             2                       Japan                   JPN
# 12      False             3                      Sweden                   SWE
# 13      False             4                 Switzerland                   SUI
# 14      False             5                      Canada                   CAN
# 15      False             6    United States of America                   USA
# 16      False             7  People's Republic of China                   CHN
# 17      False             8           Republic of Korea                   KOR
# 18      False             9                     Denmark                   DEN
# 19      False            10                         ROC                   ROC
# 20      False             1                      Sweden                   SWE
# 21      False             2               Great Britain                   GBR
# 22      False             3                      Canada                   CAN
# 23      False             4    United States of America                   USA
# 24      False             5  People's Republic of China                   CHN
# 25      False             6                      Norway                   NOR
# 26      False             7                 Switzerland                   SUI
# 27      False             8                         ROC                   ROC
# 28      False             9                       Italy                   ITA
# 29      False            10                     Denmark                   DEN
# 30      False             6                   Australia                   AUS
# 31      False            17                      Sweden                   SWE
# 32      False            16    United States of America                   USA
# 33      False            19                     Finland                   FIN
# 34      False             8                  Kazakhstan                   KAZ
# 35      False            29                   Australia                   AUS
# 36      False             3                       Japan                   JPN
# 37      False             7                       Japan                   JPN
# 38      False            26                      Canada                   CAN
# 39      False            24                   Australia                   AUS
# 40      False            21                  Kazakhstan                   KAZ
# 41      False             9                       Japan                   JPN
# 42      False            10                   Australia                   AUS
# 43      False            28                     Finland                   FIN
# 44      False            18                 Switzerland                   SUI
# 45      False            27               Great Britain                   GBR
# 46      False             2                      Canada                   CAN
# 47      False            23                       Japan                   JPN
# 48      False             1                      Sweden                   SWE
# 49      False            25    United States of America                   USA
#
#                                                 athlete_url value_unit  \
# 0                                                       NaN        NaN
# 1                                                       NaN        NaN
# 2                                                       NaN        NaN
# 3                                                       NaN        NaN
# 4                                                       NaN        NaN
# 5                                                       NaN        NaN
# 6                                                       NaN        NaN
# 7                                                       NaN        NaN
# 8                                                       NaN        NaN
# 9                                                       NaN        NaN
# 10                                                      NaN        NaN
# 11                                                      NaN        NaN
# 12                                                      NaN        NaN
# 13                                                      NaN        NaN
# 14                                                      NaN        NaN
# 15                                                      NaN        NaN
# 16                                                      NaN        NaN
# 17                                                      NaN        NaN
# 18                                                      NaN        NaN
# 19                                                      NaN        NaN
# 20                                                      NaN        NaN
# 21                                                      NaN        NaN
# 22                                                      NaN        NaN
# 23                                                      NaN        NaN
# 24                                                      NaN        NaN
# 25                                                      NaN        NaN
# 26                                                      NaN        NaN
# 27                                                      NaN        NaN
# 28                                                      NaN        NaN
# 29                                                      NaN        NaN
# 30  https://olympics.com/en/athletes/cooper-woods-topalovic      76.74
# 31                https://olympics.com/en/athletes/elofsson      78.87
# 32           https://olympics.com/en/athletes/dylan-walczyk      75.86
# 33           https://olympics.com/en/athletes/olli-penttala      75.95
# 34                https://olympics.com/en/athletes/reikherd      75.43
# 35             https://olympics.com/en/athletes/matt-graham      65.13
# 36         https://olympics.com/en/athletes/ikuma-horishima      76.19
# 37             https://olympics.com/en/athletes/daichi-hara      76.11
# 38          https://olympics.com/en/athletes/laurent-dumais      71.39
# 39          https://olympics.com/en/athletes/james-matheson      73.20
# 40          https://olympics.com/en/athletes/pavel-kolmakov      74.09
# 41         https://olympics.com/en/athletes/kosuke-sugimoto      76.26
# 42          https://olympics.com/en/athletes/brodie-summers      77.93
# 43          https://olympics.com/en/athletes/severi-vierela      69.16
# 44              https://olympics.com/en/athletes/marco-tade      74.48
# 45         https://olympics.com/en/athletes/william-feneley      70.23
# 46        https://olympics.com/en/athletes/mikael-kingsbury      81.15
# 47              https://olympics.com/en/athletes/so-matsuda      73.35
# 48                https://olympics.com/en/athletes/wallberg      79.12
# 49          https://olympics.com/en/athletes/bradley-wilson      72.94
#
#    value_type first_name        last_name athlete1_first_name  \
# 0         NaN                         Nan            Stefania
# 1         NaN                         Nan             Kristin
# 2         NaN                         Nan              Almida
# 3         NaN                         Nan            Jennifer
# 4         NaN                         Nan              Rachel
# 5         NaN                         Nan              Zuzana
# 6         NaN                         Nan               Jenny
# 7         NaN                         Nan               Vicky
# 8         NaN                         Nan              Suyuan
# 9         NaN                         Nan               Tahli
# 10        NaN                         Nan                None
# 11        NaN                         Nan                None
# 12        NaN                         Nan                None
# 13        NaN                         Nan                None
# 14        NaN                         Nan                None
# 15        NaN                         Nan                None
# 16        NaN                         Nan                None
# 17        NaN                         Nan                None
# 18        NaN                         Nan                None
# 19        NaN                         Nan                None
# 20        NaN                         Nan                None
# 21        NaN                         Nan                None
# 22        NaN                         Nan                None
# 23        NaN                         Nan                None
# 24        NaN                         Nan                None
# 25        NaN                         Nan                None
# 26        NaN                         Nan                None
# 27        NaN                         Nan                None
# 31                None               None
# 32                None               None
# 33                None               None
# 34                None               None
# 35                None               None
# 36                None               None
# 37                None               None
# 38                None               None
# 39                None               None
# 40                None               None
# 41                None               None
# 42                None               None
# 43                None               None
# 44                None               None
# 45                None               None
# 46                None               None
# 47                None               None
# 48                None               None
# 49                None               None
#
#                                            athlete2_url
# 0         https://olympics.com/en/athletes/amos-mosaner
# 1   https://olympics.com/en/athletes/magnus-nedregotten
# 2       https://olympics.com/en/athletes/oskar-eriksson
# 3          https://olympics.com/en/athletes/bruce-mouat
# 4          https://olympics.com/en/athletes/john-morris
# 5           https://olympics.com/en/athletes/tomas-paul
# 6                 https://olympics.com/en/athletes/rios
# 7     https://olympics.com/en/athletes/christopher-plys
# 8             https://olympics.com/en/athletes/zhi-ling
# 9          https://olympics.com/en/athletes/dean-hewitt
# 10                                                 None
# 11                                                 None
# 12                                                 None
# 13                                                 None
# 14                                                 None
# 15                                                 None
# 16                                                 None
# 17                                                 None
# 18                                                 None
# 19                                                 None
# 20                                                 None
# 21                                                 None
# 22                                                 None
# 23                                                 None
# 24                                                 None
# 25                                                 None
# 26                                                 None
# 27                                                 None
# 28                                                 None
# 29                                                 None
# 30                                                 None
# 31                                                 None
# 32                                                 None
# 33                                                 None
# 34                                                 None
# 35                                                 None
# 36                                                 None
# 37                                                 None
# 38                                                 None
# 39                                                 None
# 40                                                 None
# 41                                                 None
# 42                                                 None
# 43                                                 None
# 44                                                 None
# 45                                                 None
# 46                                                 None
# 47                                                 None
# 48                                                 None
# 49                                                 None

# %%
results_data.columns
# Out:
# Index(['discipline_title', 'event_title', 'slug_game', 'participant_type',
#        'medal_type', 'rank_equal', 'rank_position', 'country_name',
#        'country_3_letter_code', 'athlete_url', 'value_unit', 'value_type',
#        'first_name', 'last_name', 'athlete1_first_name', 'athlete1_last_name',
#        'athlete1_url', 'athlete2_first_name', 'athlete2_last_name',
#        'athlete2_url'],
#       dtype='object')

# %%
# Filter the DataFrame based on participant_type
game_team_data = results_data[results_data['participant_type'] == 'GameTeam']

# Selecting columns related to athlete 1 and athlete 2
athlete_columns = ['athlete1_first_name', 'athlete1_last_name', 'athlete1_url',
                   'athlete2_first_name', 'athlete2_last_name', 'athlete2_url']

# Creating a new DataFrame with only the selected columns for GameTeam participants
game_team_athletes_data = game_team_data[athlete_columns].copy()

# Displaying the first few rows of the new DataFrame
game_team_athletes_data.head(50)
# Out:
#     athlete1_first_name athlete1_last_name  \
# 0              Stefania        Constantini
# 1               Kristin           Skaslien
# 2                Almida             De Val
# 3              Jennifer              Dodds
# 4                Rachel              Homan
# 5                Zuzana            Hajkova
# 6                 Jenny             Perret
# 7                 Vicky          Persinger
# 8                Suyuan                Fan
# 9                 Tahli               Gill
# 10                 None               None
# 11                 None               None
# 12                 None               None
# 13                 None               None
# 14                 None               None
# 15                 None               None
# 16                 None               None
# 17                 None               None
# 18                 None               None
# 19                 None               None
# 20                 None               None
# 21                 None               None
# 22                 None               None
# 23                 None               None
# 24                 None               None
# 25                 None               None
# 26                 None               None
# 27                 None               None
# 28                 None               None
# 9           https://olympics.com/en/athletes/dean-hewitt
# 10                                                  None
# 11                                                  None
# 12                                                  None
# 13                                                  None
# 14                                                  None
# 15                                                  None
# 16                                                  None
# 17                                                  None
# 18                                                  None
# 19                                                  None
# 20                                                  None
# 21                                                  None
# 22                                                  None
# 23                                                  None
# 24                                                  None
# 25                                                  None
# 26                                                  None
# 27                                                  None
# 28                                                  None
# 29                                                  None
# 202                                                 None
# 203                                                 None
# 204                                                 None
# 205                                                 None
# 206                                                 None
# 207                                                 None
# 425                                                 None
# 426                                                 None
# 427                                                 None
# 428                                                 None
# 429                                                 None
# 430                                                 None
# 431                                                 None
# 432                                                 None
# 433                                                 None
# 434                                                 None
# 435                                                 None
# 436                                                 None
# 437                                                 None
# 438                                                 None

# %%
# Filter the DataFrame based on participant_type
athlete_data = results_data[results_data['participant_type'] == 'Athlete']

# Separate first_name and last_name
first_name = athlete_data['first_name'].copy()
last_name = athlete_data['last_name'].copy()

# For rows where last_name is NaN, fill it with an empty string
last_name.fillna('', inplace=True)

# Create a new DataFrame with separated first_name and last_name
athlete_names = pd.DataFrame({
    'first_name': first_name,
    'last_name': last_name
})

# Displaying the first few rows of the new DataFrame
athlete_names.head()
# Out:
#    first_name        last_name
# 30     Cooper  Woods-topalovic
# 31      Felix         Elofsson
# 32      Dylan          Walczyk
# 33       Olli         Penttala
# 34    Dmitriy         Reikherd

# %%
print(athlete_data['participant_type'].unique())
print(game_team_data['participant_type'].unique())
# Out:
# ['Athlete']
# ['GameTeam']

# %%
# Create a copy of the DataFrame to avoid the SettingWithCopyWarning
athlete_data = athlete_data.copy()
game_team_data = game_team_data.copy()

# Create a new column with constant value to perform Cartesian product merge
athlete_data['key'] = 1
game_team_data['key'] = 1

# Concatenate the DataFrames along the rows axis
merged_data = pd.concat([athlete_data, game_team_data], ignore_index=True)

# Drop the key column
merged_data.drop(columns='key', inplace=True)

# Display the merged DataFrame
merged_data.head(50)
# Out:
#     discipline_title             event_title     slug_game participant_type  \
# 0   Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 1   Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 2   Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 3   Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 4   Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 5   Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 6   Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 7   Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 8   Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 9   Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 10  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 11  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 12  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 13  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 14  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 15  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 16  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 17  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 18  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 19  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 20  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 21  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 22  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 23  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 24  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 25  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 26  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 27  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 28  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 29  Freestyle Skiing            Men's Moguls  beijing-2022          Athlete
# 30  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 31  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 32  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 33  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 34  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 35  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 36  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 37  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 38  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 39  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 40  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 41  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 42  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 43  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 44  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 45  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 46  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 47  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 48  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
# 49  Freestyle Skiing  Men's Freeski Halfpipe  beijing-2022          Athlete
#
#    medal_type rank_equal rank_position                country_name  \
# 0         NaN      False             6                   Australia
# 1         NaN      False            17                      Sweden
# 2         NaN      False            16    United States of America
# 3         NaN      False            19                     Finland
# 4         NaN      False             8                  Kazakhstan
# 5         NaN      False            29                   Australia
# 6      BRONZE      False             3                       Japan
# 7         NaN      False             7                       Japan
# 8         NaN      False            26                      Canada
# 9         NaN      False            24                   Australia
# 10        NaN      False            21                  Kazakhstan
# 11        NaN      False             9                       Japan
# 12        NaN      False            10                   Australia
# 13        NaN      False            28                     Finland
# 14        NaN      False            18                 Switzerland
# 15        NaN      False            27               Great Britain
# 16     SILVER      False             2                      Canada
# 17        NaN      False            23                       Japan
# 18       GOLD      False             1                      Sweden
# 19        NaN      False            25    United States of America
# 20        NaN      False            30  People's Republic of China
# 21        NaN      False             4                      France
# 22        NaN      False            14    United States of America
# 23        NaN      False             5    United States of America
# 24        NaN      False            11                      France
# 25        NaN      False            20                     Finland
# 26        NaN      False            13                         ROC
# 27        NaN      False            12                         ROC
# 28        NaN      False            15                      Sweden
# 29        NaN      False            22                      Sweden
# 30        NaN      False            14  People's Republic of China
# 31        NaN      False             6                      France
# 32        NaN      False             4                      Canada
# 33        NaN      False            12                 Switzerland
# 34       GOLD      False             1                 New Zealand
# 35        NaN      False            16           Republic of Korea
# 36     SILVER      False             2    United States of America
# 37        NaN      False             7    United States of America
# 38        NaN      False             9                      Canada
# 39        NaN      False            13                 New Zealand
# 40        NaN      False            18  People's Republic of China
# 41     BRONZE      False             3    United States of America
# 42        NaN      False            11                 New Zealand
# 43        NaN      False            20                     Ireland
# 44        NaN      False             8               Great Britain
# 45        NaN      False            19                 New Zealand
# 46        NaN      False            22  People's Republic of China
# 47        NaN      False            17                     Austria
# 48        NaN      False            21  People's Republic of China
# 49        NaN      False             5    United States of America
#
#    country_3_letter_code  \
# 0                    AUS
# 1                    SWE
# 2                    USA
# 3                    FIN
# 4                    KAZ
# 5                    AUS
# 6                    JPN
# 7                    JPN
# 8                    CAN
# 9                    AUS
# 10                   KAZ
# 11                   JPN
# 12                   AUS
# 13                   FIN
# 14                   SUI
# 15                   GBR
# 16                   CAN
# 17                   JPN
# 18                   SWE
# 19                   USA
# 20                   CHN
# 21                   FRA
# 22                   USA
# 23                   USA
# 24                   FRA
# 25                   FIN
# 26                   ROC
# 27                   ROC
# 28                   SWE
# 29                   SWE
# 30                   CHN
# 31                   FRA
# 32                   CAN
# 33                   SUI
# 34                   NZL
# 35                   KOR
# 36                   USA
# 37                   USA
# 38                   CAN
# 39                   NZL
# 40                   CHN
# 41                   USA
# 42                   NZL
# 43                   IRL
# 44                   GBR
# 45                   NZL
# 46                   CHN
# 47                   AUT
# 48                   CHN
# 49                   USA
#
#                                                 athlete_url value_unit  \
# 0   https://olympics.com/en/athletes/cooper-woods-topalovic      76.74
# 1                 https://olympics.com/en/athletes/elofsson      78.87
# 2            https://olympics.com/en/athletes/dylan-walczyk      75.86
# 3            https://olympics.com/en/athletes/olli-penttala      75.95
# 4                 https://olympics.com/en/athletes/reikherd      75.43
# 5              https://olympics.com/en/athletes/matt-graham      65.13
# 6          https://olympics.com/en/athletes/ikuma-horishima      76.19
# 7              https://olympics.com/en/athletes/daichi-hara      76.11
# 8           https://olympics.com/en/athletes/laurent-dumais      71.39
# 9           https://olympics.com/en/athletes/james-matheson      73.20
# 10          https://olympics.com/en/athletes/pavel-kolmakov      74.09
# 11         https://olympics.com/en/athletes/kosuke-sugimoto      76.26
# 12          https://olympics.com/en/athletes/brodie-summers      77.93
# 13          https://olympics.com/en/athletes/severi-vierela      69.16
